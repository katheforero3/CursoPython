# %% [markdown]
# <a href="https://colab.research.google.com/github/katheforero3/CursoPython/blob/main/Visualizaciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Visualizaciones**
#
# Curso Python
#
# Unicafam
#
# Estudiantes: Katherine Forero
#
# Docente: Nicolas Mojica

# %%
#Librerias
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
comparacion_ventas_exp=pd.read_csv("/content/comparacion_ventas_exp.csv")
composicion_mercado_exp=pd.read_csv("/content/composicion_mercado_exp.csv")
correlacion_marketing_exp=pd.read_csv("/content/correlacion_marketing_exp.csv")
distribucion_tiempos_exp=pd.read_csv("/content/distribucion_tiempos_exp.csv")

# %% [markdown]
# **Grafica de correlación**

# %%
correlacion_marketing_exp.head(5)
# Out:
#    Campaña ID  Inversión en marketing (USD)  Ventas generadas (USD)  \
# 0           1                          5000                   25000
# 1           2                         10000                   60000
# 2           3                          7500                   40000
# 3           6                          6000                   30000
# 4           1                          5000                   25000
#
#   Fecha de la campaña
# 0          2024-01-15
# 1          2024-02-20
# 2          2024-03-10
# 3          2024-06-15
# 4          2024-01-15

# %%
#Grafica de correlación de inversión vs ventas generadas
#df=sns.load_dataset('correlacion_marketing_exp')

sns.scatterplot(x=correlacion_marketing_exp['Inversión en marketing (USD)'], y=correlacion_marketing_exp['Inversión en marketing (USD)'])
# Out:
# <Axes: xlabel='Inversión en marketing (USD)', ylabel='Inversión en marketing (USD)'>

# %%
sns.scatterplot(x=correlacion_marketing_exp['Inversión en marketing (USD)'],
                y=correlacion_marketing_exp['Inversión en marketing (USD)'],color='green')
# Out:
# <Axes: xlabel='Inversión en marketing (USD)', ylabel='Inversión en marketing (USD)'>

# %%
sns.scatterplot(x=correlacion_marketing_exp['Inversión en marketing (USD)'],
                y=correlacion_marketing_exp['Inversión en marketing (USD)'],
                hue=correlacion_marketing_exp['Campaña ID'],legend=True)
# Out:
# <Axes: xlabel='Inversión en marketing (USD)', ylabel='Inversión en marketing (USD)'>

# %%
#Grafica de Heatmap

sns.heatmap(correlacion_marketing_exp[['Inversión en marketing (USD)', 'Ventas generadas (USD)']])
# Out:
# <Axes: >

# %%
comparacion_ventas_exp
# Out:
#          Fecha Región Producto  Ventas
# 0   2024-01-01  Norte        A   12000
# 1   2024-01-01    Sur        B   15000
# 2   2024-02-01   Este        A   18000
# 3   2024-03-01    Sur        C   11000
# 4   2024-01-01  Norte        A   12000
# ..         ...    ...      ...     ...
# 95  2024-03-01  Norte        B   16000
# 96  2024-02-01   Este        A   18000
# 97  2024-01-01  Norte        A   12000
# 98  2024-03-01    Sur        C   11000
# 99  2024-02-01   Este        A   18000
#
# [100 rows x 4 columns]

# %%
comparacion_ventas_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Fecha     100 non-null    object
#  1   Región    100 non-null    object
#  2   Producto  100 non-null    object
#  3   Ventas    100 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 3.2+ KB

# %%
#Graficas de Comparación

#Nombre de los ejes

x=pd.to_datetime(comparacion_ventas_exp['Fecha'])
y=comparacion_ventas_exp['Ventas']
gig,ax=plt.subplots()
ax.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Grafica de Composición
composicion_mercado_exp
# Out:
#    Empresa Producto  Participación (%) Trimestre
# 0   X Corp        A                 20   Q1 2024
# 1   Y Corp        B                 30   Q1 2024
# 2    Z Inc        A                 15   Q1 2024
# 3    Z Inc        B                 20   Q2 2024
# 4   X Corp        A                 20   Q1 2024
# ..     ...      ...                ...       ...
# 95  Y Corp        A                 10   Q2 2024
# 96   Z Inc        A                 15   Q1 2024
# 97  X Corp        A                 20   Q1 2024
# 98   Z Inc        B                 20   Q2 2024
# 99   Z Inc        A                 15   Q1 2024
#
# [100 rows x 4 columns]

# %%
#Filtar datos en Q1=2024
grafica_composicion = composicion_mercado_exp[
    (composicion_mercado_exp['Trimestre'] == "Q1 2024") &
    (composicion_mercado_exp['Empresa'] == "X Corp")
]
grafica_composicion
# Out:
#    Empresa Producto  Participación (%) Trimestre
# 0   X Corp        A                 20   Q1 2024
# 4   X Corp        A                 20   Q1 2024
# 6   X Corp        A                 20   Q1 2024
# 9   X Corp        A                 20   Q1 2024
# 10  X Corp        A                 20   Q1 2024
# 18  X Corp        A                 20   Q1 2024
# 30  X Corp        A                 20   Q1 2024
# 37  X Corp        A                 20   Q1 2024
# 45  X Corp        A                 20   Q1 2024
# 53  X Corp        A                 20   Q1 2024
# 59  X Corp        A                 20   Q1 2024
# 60  X Corp        A                 20   Q1 2024
# 61  X Corp        A                 20   Q1 2024
# 65  X Corp        A                 20   Q1 2024
# 75  X Corp        A                 20   Q1 2024
# 80  X Corp        A                 20   Q1 2024
# 97  X Corp        A                 20   Q1 2024

# %%
tamano_grupos=[12,11,3,30]
#Creación de la grafica
plt.pie(tamano_grupos)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Graffica de Distribución

sns.boxplot(x=distribucion_tiempos_exp['Fecha de creación'],y=distribucion_tiempos_exp['Tiempo de respuesta (horas)'])
distribucion_tiempos_exp
# Out:
#     Ticket ID Fecha de creación  Tiempo de respuesta (horas)
# 0           1        2024-07-01                          2.5
# 1           2        2024-07-01                          1.0
# 2           3        2024-07-02                          4.5
# 3           6        2024-07-03                          1.5
# 4           1        2024-07-01                          2.5
# ..        ...               ...                          ...
# 95          5        2024-07-03                          3.0
# 96          3        2024-07-02                          4.5
# 97          1        2024-07-01                          2.5
# 98          6        2024-07-03                          1.5
# 99          3        2024-07-02                          4.5
#
# [100 rows x 3 columns]
