# %% [markdown]
# <a href="https://colab.research.google.com/github/katheforero3/CursoPython/blob/main/Librerias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Librerias**
#
# Curso Python
#
# Unicafam
#
# Estudiantes: Katherine Forero
#
# Docente: Nicolas Mojica

# %%
#Instalación de librerias
import pandas as pd
import numpy as np

# %%
#Cargar un dataframe dentro de una variable a traves de la libreria pandas
marketing_data=pd.read_csv("/content/sample_data/correlacion_marketing_exp.csv")

# %%
marketing_data
# Out:
#     Campaña ID  Inversión en marketing (USD)  Ventas generadas (USD)  \
# 0            1                          5000                   25000
# 1            2                         10000                   60000
# 2            3                          7500                   40000
# 3            6                          6000                   30000
# 4            1                          5000                   25000
# ..         ...                           ...                     ...
# 95           5                          8000                   45000
# 96           3                          7500                   40000
# 97           1                          5000                   25000
# 98           6                          6000                   30000
# 99           3                          7500                   40000
#
#    Fecha de la campaña
# 0           2024-01-15
# 1           2024-02-20
# 2           2024-03-10
# 3           2024-06-15
# ...

# %%
marketing_data['Inversión en marketing (USD)']
# Out:
# 0      5000
# 1     10000
# 2      7500
# 3      6000
# 4      5000
#       ...
# 95     8000
# 96     7500
# 97     5000
# 98     6000
# 99     7500
# Name: Inversión en marketing (USD), Length: 100, dtype: int64

# %%
#Información acerca del dataset
marketing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Campaña ID                    100 non-null    int64
#  1   Inversión en marketing (USD)  100 non-null    int64
#  2   Ventas generadas (USD)        100 non-null    int64
#  3   Fecha de la campaña           100 non-null    object
# dtypes: int64(3), object(1)
# memory usage: 3.2+ KB

# %%
#Medidas de tendencia central
marketing_data.describe()
# Out:
#        Campaña ID  Inversión en marketing (USD)  Ventas generadas (USD)
# count  100.000000                    100.000000              100.000000
# mean     3.500000                   6450.000000            36000.000000
# std      1.732051                   2520.121049            14616.304719
# min      1.000000                   2000.000000            15000.000000
# 25%      2.000000                   5000.000000            25000.000000
# 50%      3.500000                   6750.000000            35000.000000
# 75%      5.000000                   8000.000000            45000.000000
# max      6.000000                  10000.000000            60000.000000

# %%
#Operaciones de reducción
total_inversion_marketing=marketing_data['Inversión en marketing (USD)'].sum()
print(total_inversion_marketing)
# Out:
# 645000

# %%
#Inserción de una nueva columna en dataset
marketing_data['utilidad'] = marketing_data['Ventas generadas (USD)'] - marketing_data['Inversión en marketing (USD)']
marketing_data
# Out:
#     Campaña ID  Inversión en marketing (USD)  Ventas generadas (USD)  \
# 0            1                          5000                   25000
# 1            2                         10000                   60000
# 2            3                          7500                   40000
# 3            6                          6000                   30000
# 4            1                          5000                   25000
# ..         ...                           ...                     ...
# 95           5                          8000                   45000
# 96           3                          7500                   40000
# 97           1                          5000                   25000
# 98           6                          6000                   30000
# 99           3                          7500                   40000
#
#    Fecha de la campaña  utilidad
# 0           2024-01-15     20000
# 1           2024-02-20     50000
# 2           2024-03-10     32500
# ...

# %%
#Carga dataset
data_ejecutivos=pd.read_excel('/content/sample_data/Taller2_ETL.xlsx',sheet_name='Ejecutivos')
data_ejecuciones=pd.read_excel('/content/sample_data/Taller2_ETL.xlsx',sheet_name='BaseEjecuciones')

# %%
data_ejecutivos
# Out:
#          CEDULA  COD OFICINA   CODIGO GESTOR               OFICINA  \
# 0       9375240            12           9658      BOGOTÁ CHAPINERO
# 1    1023008416            73           9877       BOGOTÁ RESTREPO
# 2      41960913           228          31597        ARMENIA CENTRO
# 3    1010229345           280          36873   BOGOTÁ LOS HAYUELOS
# 4    1054920307           203           9817  PEREIRA DOSQUEBRADAS
# ..          ...           ...            ...                   ...
# 476  1019088583            51          38234       BOGOTÁ GALERIAS
# 477    80807040           634           9196  BOGOTÁ SUBA IMPERIAL
# 478    80058124           757           9863              MOSQUERA
# 479    52067261            37           9905      BOGOTÁ UNICENTRO
# 480  1088008856           206          37379  PEREIRA CRA. SEPTIMA
#
#                                 NOMBRE JORNADA  ZONA
# 0             LUIS JAVIER FUENTES LEON  NORMAL  9002
# 1         RUBEN DARIO JIMENEZ PRECIADO  NORMAL  9004
# ...

# %%
data_ejecuciones
# Out:
#          CEDULA  N° Cuentas  N° CDT  N° Tarjetas De Crédito  \
# 0       9375240          64       2                      12
# 1    1023008416          93       6                      16
# 2      41960913          61       3                      10
# 3    1010229345          63       2                      14
# 4    1054920307          80       3                      15
# ..          ...         ...     ...                     ...
# 490  1019088583          50       3                       2
# 491    80807040          85       9                      12
# 492    80058124          74       1                       8
# 493    52067261          78       6                      12
# 494  1088008856          99       6                      19
#
#      N° Debitos Automáticos  Plan Familia (Millones)  Consumo (Millones)  \
# 0                         1             6.150000e+06        8.500000e+07
# 1                        10             9.930000e+06        9.197159e+07
# ...

# %%
#Merge de datos
ejecutivos_ejecuciones=pd.merge(data_ejecutivos,data_ejecuciones,how='inner',on='CEDULA')
ejecutivos_ejecuciones
# Out:
#          CEDULA  COD OFICINA   CODIGO GESTOR               OFICINA  \
# 0       9375240            12           9658      BOGOTÁ CHAPINERO
# 1    1023008416            73           9877       BOGOTÁ RESTREPO
# 2      41960913           228          31597        ARMENIA CENTRO
# 3    1010229345           280          36873   BOGOTÁ LOS HAYUELOS
# 4    1054920307           203           9817  PEREIRA DOSQUEBRADAS
# ..          ...           ...            ...                   ...
# 476  1019088583            51          38234       BOGOTÁ GALERIAS
# 477    80807040           634           9196  BOGOTÁ SUBA IMPERIAL
# 478    80058124           757           9863              MOSQUERA
# 479    52067261            37           9905      BOGOTÁ UNICENTRO
# 480  1088008856           206          37379  PEREIRA CRA. SEPTIMA
#
#                                 NOMBRE JORNADA  ZONA  N° Cuentas  N° CDT  \
# 0             LUIS JAVIER FUENTES LEON  NORMAL  9002          64       2
# ...

# %%
#Tablas Dinamicas
tabla_dinamica=pd.pivot_table(ejecutivos_ejecuciones,
               index='ZONA',
               values='N° Tarjetas De Crédito',
               aggfunc=np.sum)
tabla_dinamica
# Out:
# <ipython-input-36-bb8f4c6771ff>:2: FutureWarning: The provided callable <function sum at 0x7d2251ff8670> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tabla_dinamica=pd.pivot_table(ejecutivos_ejecuciones,
#       N° Tarjetas De Crédito
# ZONA
# 9001                     565
# 9002                     411
# 9003                     470
# 9004                     490
# 9005                     557
# 9006                     457
# 9007                     443
# 9008                     379
# 9009                     397

# %%
#Eliminar columna
marketing_data=marketing_data.drop('utilidad',axis='columns')
marketing_data
# Out:
#     Campaña ID  Inversión en marketing (USD)  Ventas generadas (USD)  \
# 0            1                          5000                   25000
# 1            2                         10000                   60000
# 2            3                          7500                   40000
# 3            6                          6000                   30000
# 4            1                          5000                   25000
# ..         ...                           ...                     ...
# 95           5                          8000                   45000
# 96           3                          7500                   40000
# 97           1                          5000                   25000
# 98           6                          6000                   30000
# 99           3                          7500                   40000
#
#    Fecha de la campaña
# 0           2024-01-15
# 1           2024-02-20
# 2           2024-03-10
# 3           2024-06-15
# ...
